# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/madhumitha/Downloads/LifeExpectancyData.csv")
df
# Out:
#           Country  Year      Status  LifeExpectancy  AdultMortality  \
# 0     Afghanistan  2015  Developing            65.0           263.0
# 1     Afghanistan  2014  Developing            59.9           271.0
# 2     Afghanistan  2013  Developing            59.9           268.0
# 3     Afghanistan  2012  Developing            59.5           272.0
# 4     Afghanistan  2011  Developing            59.2           275.0
# ...           ...   ...         ...             ...             ...
# 2933     Zimbabwe  2004  Developing            44.3           723.0
# 2934     Zimbabwe  2003  Developing            44.5           715.0
# 2935     Zimbabwe  2002  Developing            44.8            73.0
# 2936     Zimbabwe  2001  Developing            45.3           686.0
# 2937     Zimbabwe  2000  Developing            46.0           665.0
#
#       InfantDeaths  Alcohol  PercentageExpenditure  HepatitisB  Measles  ...  \
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'LifeExpectancy', 'AdultMortality',
#        'InfantDeaths', 'Alcohol', 'PercentageExpenditure', 'HepatitisB',
#        'Measles', 'BMI', 'underfivedeaths', 'Polio', 'TotalExpenditure',
#        'Diphtheria', 'HIV/AIDS', 'GDP', 'Population', 'thinness1-19years',
#        'thinness5-9years', 'IncomeCompositionOfResources', 'Schooling'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Country                           0
# Year                              0
# Status                            0
# LifeExpectancy                   10
# AdultMortality                   10
# InfantDeaths                      0
# Alcohol                         194
# PercentageExpenditure             0
# HepatitisB                      553
# Measles                           0
# BMI                              34
# underfivedeaths                   0
# Polio                            19
# TotalExpenditure                226
# Diphtheria                       19
# HIV/AIDS                          0
# GDP                             448
# Population                      652
# thinness1-19years                34
# thinness5-9years                 34
# IncomeCompositionOfResources    167
# Schooling                       163
# dtype: int64

# %%
corr_df=df.corr()
corr_df
# Out:
#                                   Year  LifeExpectancy  AdultMortality  \
# Year                          1.000000        0.170033       -0.079052
# LifeExpectancy                0.170033        1.000000       -0.696359
# AdultMortality               -0.079052       -0.696359        1.000000
# InfantDeaths                 -0.037415       -0.196557        0.078756
# Alcohol                      -0.052990        0.404877       -0.195848
# PercentageExpenditure         0.031400        0.381864       -0.242860
# HepatitisB                    0.104333        0.256762       -0.162476
# Measles                      -0.082493       -0.157586        0.031176
# BMI                           0.108974        0.567694       -0.387017
# underfivedeaths              -0.042937       -0.222529        0.094146
# Polio                         0.094158        0.465556       -0.274823
# TotalExpenditure              0.090740        0.218086       -0.115281
# ...

# %%
sns.heatmap(corr_df)

# %%
sns.relplot(x='Schooling',y='LifeExpectancy',data=df)

# %%
#imputing with categorical mean
def impute_schooling(cols):
    s=cols[0]
    l=cols[1]
    if pd.isnull(s):
        if l<= 40:
            return 8.0
        elif 40<l<=44:
            return 7.5
        elif 44<l<50:
            return 8.1
        elif 50<l<=60:
            return 8.2
        elif 60<l<=70:
            return 10.5
        elif 70<l<=80:
            return 13.4
        elif l>80:
            return 16.5
    else:
        return s
    
df['Schooling']=df[['Schooling','LifeExpectancy']].apply(impute_schooling,axis=1)

# %%
#Analysing the outliers in each category
print(df['Population'].mean())
sns.set(style="whitegrid")
sns.boxplot(x=df["Population"])
# Out:
# 12753375.120052498

# %%
print(df['HepatitisB'].mean())
sns.set(style="whitegrid")
sns.boxplot(x=df["HepatitisB"])
# Out:
# 80.94046121593291

# %%
print(df['LifeExpectancy'].mean())
sns.set(style="whitegrid")
sns.boxplot(x=df["LifeExpectancy"])
# Out:
# 69.22493169398912

# %%
print(df['HIV/AIDS'].mean())
sns.set(style="whitegrid")
sns.boxplot(x=df['HIV/AIDS'])
# Out:
# 1.7421034717494939

# %%
print(df['TotalExpenditure'].mean())
sns.set(style="whitegrid")
sns.boxplot(x=df["TotalExpenditure"])
# Out:
# 5.9381895280235915

# %%
print(df['AdultMortality'].mean())
sns.set(style="whitegrid")
sns.boxplot(x=df['AdultMortality'])
# Out:
# 164.79644808743168

# %%
#REMOVING OUTLIERS
df=df.loc[df["Population"]<1093859294]
df=df.loc[df['HepatitisB']>=30]
df=df.loc[df['LifeExpectancy']>15]
df=df.loc[df['HIV/AIDS']<40]
df=df.loc[df['TotalExpenditure']<15]
df=df.loc[df['AdultMortality']<750]

# %%
#imputing the null values
df["Population"].fillna(df["Population"].mean(), inplace=True)
df.dropna(subset = ["Alcohol"], inplace=True)
df["GDP"].fillna(df["GDP"].median(), inplace=True)
df["BMI"].fillna(df["BMI"].median(), inplace=True)
df["TotalExpenditure"].fillna(df["TotalExpenditure"].median(), inplace=True)
df["Polio"].fillna(df["Polio"].median(), inplace=True)
df["Diphtheria"].fillna(df["Diphtheria"].median(), inplace=True)
df=df.dropna()
df
# Out:
#           Country  Year      Status  LifeExpectancy  AdultMortality  \
# 0     Afghanistan  2015  Developing            65.0           263.0
# 1     Afghanistan  2014  Developing            59.9           271.0
# 2     Afghanistan  2013  Developing            59.9           268.0
# 3     Afghanistan  2012  Developing            59.5           272.0
# 4     Afghanistan  2011  Developing            59.2           275.0
# ...           ...   ...         ...             ...             ...
# 2930     Zimbabwe  2007  Developing            46.6            67.0
# 2931     Zimbabwe  2006  Developing            45.4             7.0
# 2932     Zimbabwe  2005  Developing            44.6           717.0
# 2933     Zimbabwe  2004  Developing            44.3           723.0
# 2935     Zimbabwe  2002  Developing            44.8            73.0
#
#       InfantDeaths  Alcohol  PercentageExpenditure  HepatitisB  Measles  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                         0
# Year                            0
# Status                          0
# LifeExpectancy                  0
# AdultMortality                  0
# InfantDeaths                    0
# Alcohol                         0
# PercentageExpenditure           0
# HepatitisB                      0
# Measles                         0
# BMI                             0
# underfivedeaths                 0
# Polio                           0
# TotalExpenditure                0
# Diphtheria                      0
# HIV/AIDS                        0
# GDP                             0
# Population                      0
# thinness1-19years               0
# thinness5-9years                0
# IncomeCompositionOfResources    0
# Schooling                       0
# dtype: int64

# %%
#using one hot encoding for segregating "developed" and "developing" countries
for ind in df.index:
    if df['Status'][ind] == 'Developed':
        df['Status'][ind] = 1
    else:
        df['Status'][ind]= 0

# %%
#converting the country names to numbers using label encoding technique
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(df['Country'])
#list(le.classes_)
le.transform(df['Country'])
# Out:
# array([  0,   0,   0, ..., 131, 131, 131])

# %%
#importing libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import yellowbrick

# %%
#featurisation
sample = df.drop(['Country','LifeExpectancy'], axis = 1)
x = sample[['Year', 'Status', 'AdultMortality', 'InfantDeaths', 'Alcohol',
       'PercentageExpenditure','HepatitisB', 'Measles', 'BMI',
       'underfivedeaths', 'Polio', 'TotalExpenditure', 'Diphtheria',
       'HIV/AIDS', 'GDP', 'Population', 'thinness1-19years',
       'thinness5-9years', 'IncomeCompositionOfResources', 'Schooling']]
y = df['LifeExpectancy']
#np.reshape(y,2103,1)
print(x.shape)
print(y.shape)
# Out:
# (1499, 20)
# (1499,)

# %%
sample.columns
# Out:
# Index(['Year', 'Status', 'AdultMortality', 'InfantDeaths', 'Alcohol',
#        'PercentageExpenditure', 'HepatitisB', 'Measles', 'BMI',
#        'underfivedeaths', 'Polio', 'TotalExpenditure', 'Diphtheria',
#        'HIV/AIDS', 'GDP', 'Population', 'thinness1-19years',
#        'thinness5-9years', 'IncomeCompositionOfResources', 'Schooling'],
#       dtype='object')

# %%
#training and evaluating the model
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30,random_state = 1)
model = LinearRegression()
model.fit(x_train,y_train)
y_pred = model.predict(x_test)
print("RMSE :",np.sqrt(mean_squared_error(y_test,y_pred)))
print("R^2 :" , r2_score(y_test,y_pred))
# Out:
# RMSE : 3.460568861812934
# R^2 : 0.8487961881914826

# %%
from yellowbrick.regressor import PredictionError, ResidualsPlot
visualizer = PredictionError(model)

visualizer.fit(x_train, y_train)  # Fit the training data to the visualizer
visualizer.score(x_test, y_test)  # Evaluate the model on the test data
visualizer.poof();

# %%
import math
example =np.array(sample.iloc[15,:])
#np.reshape(example,20)
what = np.array(example).reshape(1,20)
what
pred=model.predict(what)
if(pred>60):
    pred=math.ceil(pred)
else:
    pred= int(pred)
pred
# Out:
# 57

# %%
df.iloc[15,:]
# Out:
# Country                         Afghanistan
# Year                                   2000
# Status                                    0
# LifeExpectancy                         54.8
# AdultMortality                          321
# InfantDeaths                             88
# Alcohol                                0.01
# PercentageExpenditure                10.425
# HepatitisB                               62
# Measles                                6532
# BMI                                    12.2
# underfivedeaths                         122
# Polio                                    24
# TotalExpenditure                        8.2
# Diphtheria                               24
# HIV/AIDS                                0.1
# GDP                                  114.56
# Population                           293756
# thinness1-19years                       2.3
# thinness5-9years                        2.5
# IncomeCompositionOfResources          0.338
# ...
